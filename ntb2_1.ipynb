# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read new data
df = pd.read_csv('/home/moorche10/Desktop/note_books/divar_without_above80nan_cols.csv')
df.shape
# Out:
# /tmp/ipykernel_4926/1786747697.py:2: DtypeWarning: Columns (8,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/home/moorche10/Desktop/note_books/divar_without_above80nan_cols.csv')
# (600150, 46)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600150 entries, 0 to 600149
# Data columns (total 46 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Unnamed: 0               600150 non-null  int64
#  1   cat2_slug                600150 non-null  object
#  2   cat3_slug                600150 non-null  object
#  3   city_slug                600149 non-null  object
#  4   neighborhood_slug        241536 non-null  object
#  5   user_type                175677 non-null  object
#  6   description              600150 non-null  object
#  7   title                    600134 non-null  object
#  8   rent_mode                7 non-null       object
#  9   rent_value               6 non-null       float64
#  10  price_mode               571405 non-null  object
#  11  price_value              566150 non-null  float64
#  12  credit_mode              7 non-null       object
#  13  credit_value             6 non-null       float64
#  14  rent_credit_transform    0 non-null       float64
#  15  transformable_price      0 non-null       float64
#  16  transformable_credit     0 non-null       float64
#  17  transformable_rent       0 non-null       float64
#  18  land_size                121646 non-null  float64
#  19  building_size            596473 non-null  float64
#  20  deed_type                253008 non-null  object
#  21  floor                    307937 non-null  object
#  22  rooms_count              462615 non-null  object
#  23  total_floors_count       186704 non-null  object
#  24  unit_per_floor           184553 non-null  object
#  25  has_balcony              315852 non-null  object
#  26  has_elevator             307938 non-null  object
#  27  has_warehouse            429587 non-null  object
#  28  has_parking              429588 non-null  object
#  29  construction_year        462534 non-null  object
#  30  is_rebuilt               316037 non-null  object
#  31  has_water                23657 non-null   object
#  32  has_warm_water_provider  228299 non-null  object
#  33  has_electricity          23654 non-null   object
#  34  has_gas                  23651 non-null   object
#  35  has_heating_system       222789 non-null  object
#  36  has_cooling_system       210575 non-null  object
#  37  has_restroom             246320 non-null  object
#  38  has_barbecue             21772 non-null   object
#  39  building_direction       204694 non-null  object
#  40  has_pool                 20165 non-null   object
#  41  has_jacuzzi              19613 non-null   object
#  42  has_sauna                19427 non-null   object
#  43  floor_material           245808 non-null  object
#  44  location_latitude        391333 non-null  float64
#  45  location_longitude       391333 non-null  float64
# dtypes: float64(11), int64(1), object(34)
# memory usage: 210.6+ MB

# %%
# Delete some cols
df1 = df.drop(["rent_mode","rent_value","credit_mode","credit_value","rent_credit_transform","transformable_price",
               "transformable_credit","transformable_rent","Unnamed: 0"],axis=1)
# Out:
# (600150, 37)

# %%
# Delete some rows
df1 = df1[~df1["cat3_slug"].str.contains("shop-sell",na=True)]
df1 = df1[~df1["cat3_slug"].str.contains("office-sell",na=True)]
df1 = df1[~df1["cat3_slug"].str.contains("industry-agriculture-business-sell",na=True)]
df1 = df1[~df1["construction_year"].str.contains("قبل از 1370",na=True)]
df1 = df1.dropna(subset=["land_size"])
df1 = df1.dropna(subset=["building_size"])

# %%
df1.shape
# Out:
# (424442, 37)

# %%
# Reset indexes
df1.reset_index(inplace=True , drop=True)
df1.tail()
# Out:
#                cat2_slug         cat3_slug   city_slug    neighborhood_slug  \
# 424437  residential-sell    apartment-sell       urmia              Unknown
# 424438  residential-sell    apartment-sell      tehran  shaharak-e-moslemin
# 424439  residential-sell    apartment-sell  eslamshahr              Unknown
# 424440  residential-sell    apartment-sell  kermanshah              Unknown
# 424441  residential-sell  house-villa-sell        yazd              Unknown
#
#           user_type                                        description  \
# 424437  مشاور املاک  ➖➖➖➖➖⚜️ املاک  مهندس ⚜️➖➖➖➖➖\n\nواحد آپارتمان ...
# 424438      Unknown  بنام ایزد منان\n ۹۱ متر ۲ خواب خوش نقشه \nنورگ...
# 424439      Unknown  متریال استفاده شده در نما بهترین نوع با جزئیات...
# 424440  مشاور املاک  ~~~مشاورین املاک قبادی~~~\n■جنوبی تک واحدی\n■د...
# 424441      Unknown  سلام ودرود\nفروش منزل مسکونی واقع در خیابان ان...
#
#                                                     title price_mode  \
# 424437     آپارتمان تک واحدی / آبشناسان/ وام تا سقف ۱.۱۰۰      مقطوع
# 424438             آپارتمان ۹۱متر ۲ خواب/شهرک صاحب الزمان      مقطوع
# 424439                          اپارتمان ۱۰۵ متری خ مطهری      مقطوع
# 424440                        آپارتمان ۱۸۰ متری وحدت غربی      مقطوع
# 424441  منزل فروشی.  خیابان انقلاب   نرسیده به کارخانه...      مقطوع
#
#          price_value  land_size  ...  has_cooling_system has_restroom  \
# 424437  4.000000e+09      140.0  ...             Unknown      Unknown
# 424438  3.600000e+09       91.0  ...        water_cooler        squat
# 424439  4.350000e+09      105.0  ...     air_conditioner   squat_seat
# 424440  7.470000e+09      180.0  ...             Unknown      Unknown
# 424441  3.200000e+09      200.0  ...             Unknown      Unknown
#
#         has_barbecue  building_direction has_pool has_jacuzzi has_sauna  \
# 424437       Unknown             Unknown  Unknown     Unknown   Unknown
# 424438       Unknown               north  Unknown     Unknown   Unknown
# 424439       Unknown               south  Unknown     Unknown   Unknown
# 424440       Unknown             Unknown  Unknown     Unknown   Unknown
# 424441       Unknown             Unknown  Unknown     Unknown   Unknown
#
#        floor_material location_latitude location_longitude
# 424437        Unknown         37.505325          45.050369
# 424438   wood_parquet         35.652096          51.323963
# 424439        ceramic         35.046600          51.546260
# 424440        Unknown         34.350235          47.083241
# 424441        Unknown         35.046600          51.546260
#
# [5 rows x 37 columns]

# %%
df1.describe()
# Out:
#         price_value     land_size  building_size  location_latitude  \
# count  5.661500e+05  1.216460e+05   5.964730e+05      391333.000000
# mean   1.740030e+10  3.933626e+03   4.690200e+03          35.046600
# std    5.889907e+11  1.233283e+05   1.394032e+05           2.361010
# min    0.000000e+00  1.000000e+00   1.000000e+00          23.636976
# 25%    1.400000e+09  1.320000e+02   8.000000e+01          34.612770
# 50%    2.830000e+09  2.010000e+02   1.130000e+02          35.725151
# 75%    5.900000e+09  3.120000e+02   2.000000e+02          36.360634
# max    1.000000e+14  1.000000e+07   1.000000e+07          40.358055
#
#        location_longitude
# count       391333.000000
# mean            51.546260
# std              3.121405
# min             40.162369
# 25%             50.352402
# 50%             51.326504
# 75%             51.865124
# max             64.052490

# %%
for column in df1.columns:
    unique = df1[column].unique()
    print(f"Unique Values'{column}'=")
    print(unique)
    print(("#")*50)
# Out:
# Unique Values'cat2_slug'=
# ['residential-sell' 'real-estate-services']
# ##################################################
# Unique Values'cat3_slug'=
# ['apartment-sell' 'plot-old' 'house-villa-sell' 'partnership']
# ##################################################
# Unique Values'city_slug'=
# ['tehran' 'mashhad' 'mahdasht-city' 'pardis-city' 'ahvaz' 'gonabad' 'azna'
#  'chamestan' 'babol' 'arak' 'pishva' 'tabriz' 'urmia' 'nur' 'kish' 'yasuj'
#  'ilam' 'isfahan' 'bandar-ganaveh' 'rasht' 'sabzevar' 'karaj'
#  'andisheh-new-town' 'dezful' 'mohammadieh' 'sirjan' 'amol' 'Kordkuy'
#  'hamedan' 'qods-city' 'shandiz-city' 'mahmudabad' 'aran-va-bidgol'
#  'bandar-abbas' 'bandar-kangan' 'kiashahr' 'izadshahr' 'qazvin'
#  'khorramabad' 'kashan' 'bushehr' 'nowshahr' 'hashtgerd-city' 'behshahr'
#  'shiraz' 'sanandaj' 'masal' 'parand-city' 'shush' 'rudehen' 'torbat-jam'
#  'polsefid' 'kerman' 'saveh' 'shahriar-city' 'damghan' 'neyshabur'
#  'ramiyan' 'kahnooj' 'pakdasht-city' 'miandoab' 'amlash' 'talesh'
#  'najafabad' 'golbahar-city' 'shahrekord' 'eslamshahr' 'qom'
#  'qarchak-city' 'garmdareh' 'nashtarud' 'sari' 'saravan'
#  'astaneh-ashrafiyeh' 'kiasar' 'birjand' 'kermanshah' 'ardabil' 'yazd'
#  'borujerd' 'kahrizak' 'qeydar' 'tulam-shahr' 'alvand' 'lahijan'
#  'nahavand' 'marvdasht-city' 'zanjan' 'sarein' 'khash' 'gourab-zarmikh'
#  'khoy' 'rudsar' 'fardis-city' 'foolad-shahr' 'marivan' 'chaf-chamkhale'
#  'boroujen' 'khomam' 'zabol' 'robat-karim' 'bojnurd' 'meshgin-shahr'
#  'rafsanjan' 'quchan' 'varamin-city' 'rezvanshahr' 'ramhormoz' 'hormuz'
#  'Iranshahr' 'shahin-shahr' 'omidiyeh' 'gonbad-kavus'
#  'abbasabad-mazandaran' 'shahrud' 'minab' 'behbahan' 'sadra' 'maku'
#  'qaem-shahr' 'marand' 'golpayegan' 'zahedan' 'malayer' 'falavarjan'
#  'tonekabon' 'charbagh-alborz' 'gorgan' 'saman-city' 'lavasan-city'
#  'azadshahr-golestan' 'abadeh' 'shazand' 'nazarabad' 'firuzkooh' 'jiroft'
#  'jam' 'taft' 'dayyer' 'jahrom' 'chabahar' 'juybar' 'lashtenesha' 'royan'
#  'esfarayen' 'shahre-rey' 'javanrud' 'maragheh'
#  'safadasht-industrial-city' 'dorud' 'someh-sara' 'shushtar' 'pirbazar'
#  'abrisham-isfahan' 'kazeroon' 'hachirud' 'golestan-baharestan' 'babolsar'
#  'sarab' 'bandar-anzali' 'bahar-city' 'nasimshahr' 'khorramshahr'
#  'kouchesfahan' 'shirvan' 'torghabeh-city' 'bam' 'abyek' 'hendijan'
#  'kalale' 'fuman' 'katalem-sadatshahr' 'sahand' 'damavand'
#  'masjed-e-soleyman' 'zibakenar' 'kelarabad' 'darab' 'abadan' 'baft'
#  'vahidieh' 'absard' 'pareh-sar' 'daran' 'khorramdarreh' 'kuhdasht'
#  'chenaran' 'salman-shahr' 'izeh' 'mohammad-shahr' 'koumeleh' 'shanderman'
#  'qeshm' 'sangar' 'sorkhrood' 'sarpol-zahab' 'tankaman' 'astara'
#  'asadabad' 'baneh' 'ahmadsar-gourab' 'saqqez' 'mianeh' 'mahshahr'
#  'fasham-city' 'semnan' 'mobarakeh' 'raheem-abad' 'salmas' 'khoshkbijar'
#  'taleqan' 'bumehen' 'firuzabad' 'lavandevil' 'ashkhaneh' 'aleshtar'
#  'chalus' 'asalem' 'ramsar' 'chahar-dangeh' 'khomein' 'torbat-heydariyeh'
#  'khan-bin' 'farahabad' 'mehriz' 'khansar' 'nurabad' 'molkabad' 'galikesh'
#  'aligudarz' 'shaft' 'kelarestan' 'ferdosiye' 'chaboksar' 'neka' 'faragi'
#  'dehgolan' 'susangerd' 'aq-qala' 'eslamabad-gharb' 'langarud' 'khalkhal'
#  'koohsar' 'gahvareh' 'shahedshahr' 'fereydunkenar' 'andimeshk' 'borazjan'
#  'eshtehard' 'bonab' 'lordegan' 'abhar' 'eyvan' 'abdanan' 'garmsar'
#  'kangavar' 'rostam-abad' 'javadabad' 'takestan' 'parsabad' 'kelachay'
#  'dehdasht' 'sonqor' 'shal' 'galougah-babol' 'ahar' 'ghayen' 'azarshahr'
#  'mahan' 'negin-shahr' 'sadegh-abad' 'meybod' 'aliabad-katul' 'zarand'
#  'pol-dokhtar' 'naqadeh' 'hadi-shahr' 'siahkal' 'bandar-torkaman' 'bijar'
#  'dogonbadan' 'ardakan' 'delijan' 'babakan' 'zarghan' 'bahnamir' 'tabas'
#  'ferdows' 'bukan' 'gomishan' 'shadeghan' 'khormoj' 'khoram-abad'
#  'bandar-Imam-khomeini' 'piranshahr' 'fasa-city' 'khalil-shahr'
#  'shahin-dej' 'abali' 'norabad' 'bardsir' 'loulman' 'mehran' 'qorveh'
#  'lenjan' 'rudbar' 'kamyaran' 'sabashahr' 'roudbaneh' 'bisotun' 'germi'
#  'marzan-abad' 'shirgah' 'rostamkola' 'konarak' 'minoodasht' 'vajargah'
#  'kouhi-kheyl' 'ghamsar' 'dalkhani' 'marzikola' 'dabudasht'
#  'khomeyni-shahr' 'farim' 'tuyserkan' 'kojur' 'lisar' 'lar' 'hamidiyeh'
#  'lamerd' 'emamzadeh-abdollah' 'asara' 'ziyabar' 'dehloran' 'paeen-holar'
#  'sisakht' 'fazel-abad' 'shelman' 'eqlid' 'ziraab' 'manjil' 'pool'
#  'gazanak' 'shemshak' 'namin' 'arjmand' 'kabudrahang' 'shirud' 'eqbaliyeh'
#  'galugah-babol' 'ramshir' 'deylaman' 'mahabad' 'hamidia' 'bafq'
#  'mohajeran' 'jirandeh' 'khaf' 'sahneh' 'baghershahr' 'amirkala' 'mahalat'
#  'zargarshahr' 'tahergurab' 'baladeh' 'barah-sar' 'harsin' 'neyriz'
#  'semirom' 'otaghvar' 'khoour' 'rankouh' 'alghajar' 'makloan' 'toutkabon'
#  'zahak' 'ghorogh' 'khoshroud-pey' 'taybad' 'reyneh' 'kiakola' 'aalasht'
#  'bardaskan' 'kilan' 'sorkhan-kalateh' 'sardasht' 'haviq' 'daland' 'takht'
#  'simin-shahr' 'mazrae-katool' 'nokandeh' 'boluk' 'sangdovin' 'sourek'
#  'tabaghdeh' 'akand' 'jelin' 'farrokhshahr' 'loshan' 'chamran-town'
#  'astaneh-sara' 'bandar-gaz' 'gatab' 'dozin' 'dargahan' 'mohr'
#  'inche-borun' 'chobar' 'oshnavieh' 'masuleh' 'anbaralum' 'goli-dagh'
#  'nodeh-khandoz' 'arateh' 'yanghagh' 'khour' 'qasemabad-khaf' 'sijval'
#  'maraveh-tapeh' 'Unknown' 'tatar-olya']
# ##################################################
# Unique Values'neighborhood_slug'=
# ['gholhak' 'emamreza' 'dardasht' ... 'kuy-azadi' 'jamaran-rasht'
#  'shahid-bahonar-university']
# ##################################################
# Unique Values'user_type'=
# ['مشاور املاک' 'Unknown' 'شخصی']
# ##################################################
# Unique Values'description'=
# ['دسترسی عالی به مترو و شریعتی \nمشاعات تمیز \nبدون ایراد \nآخرین بازدید \nفروشنده واقعی\nشایان'
#  'هلدینگ ساختمانی اکبری\n\nهمراه شما هستیم برای خریدی مطمئن\n\nکلید موجود اولین بازدید ۱۰۰ در ۱۰۰ پسند\n\nمشخصات ملک:\n✨صفر کلید نخورده\n\n✨مشاعات تمام سنگ\n\n✨واحد رو به آفتاب\n\n✨پذیرایی سرتاسر پنجره\n\n✨اتاق ها هر دو\u200c نورگیر همرا به تراس رویایی\n\n✨آشپزخانه تمام چوب با نقشه عالی\n——————————————————\n\n✨با ارائه مشاوره تخصصی املاک در خدمت شما هستیم \nمشاور شما : ایرانی\n( ۲۴ ساعته پاسخگوی شما عزیزان هستم)✨\n\n⁉️برای دریافت اطلاعات بیشتر ،نحوه پرداخت و بازدید☎️ تماس حاصل فرمایید'
#  '♡♡♡♡♡♡بنام خدا♡♡♡♡♡♡\n♡♡♡عرض ادب واحترام♡♡♡\n♡♡♡♡املاک بزرگ اریو♡♡♡♡\nباافتخارازابتداتا انتهادرکنارشما\nسروران عزیزوگرامی\nکارشناس مشاور منطقه دهقان\nاپارتمان ۱۰۰متری\n۴طبقه تک واحدی\nطبقه ۳و۴ فروش\nفول امکانات\nلوکیشن موقعیت عالی\nدسترسی عالی به مترو بی ارتی وبازار روز مرکزی وفروشگاه\nفروشنده صددرصد\nبرای اطلاعات بیشتر تماس بگیرید\n       املاک اریو'
#  ...
#  'متریال استفاده شده در نما بهترین نوع با جزئیات جذاب سنگ دیواره وکف راه پله ها تمام سنگ با کیفیت  سنگ کرانیت وباطراحی مدرن سرامیک کف شفاف وکابینت ها  ممبران مدرن دارای جاروبرقی مرکزی\nدارای لابی\nدر هر اتاق خواب کمد دیواری مجزا جادار\nمجهز به سیستم اطفاء حریق و دوربین مدار بسته\nدارای پارکینگ و انباری واسانسور'
#  '~~~مشاورین املاک قبادی~~~\n■جنوبی تک واحدی\n■دارای ۳ خواب بزرگ\n■بهترین لوکیشن\n■دسترسی اسان به مراکز خرید وامکانات ■رفاهی\n■نما رومی\n■بهترین متریال \n■برای بازدید واطلاعات بیشتر به املاک مراجعه بفرمایید.'
#  'سلام ودرود\nفروش منزل مسکونی واقع در خیابان انقلاب کوچه ۷۷ \n——————————————————————\n➖۲۰۰متر \n➖چهار خواب \n➖تیراهنی \n➖فاصله چند قدمی تا خیابان انقلاب \n➖سند شش دانگ \n➖منزل بسیار تمیز \u200cسالم \n\nمعاوضه نمیشود \nقیمت:۳/۲۰۰ \n\n     ⚜️گروه مشاورین املاک میلاد⚜️\nآدرس دفتر :خیابان امام خیابان سیدالشهدا بین کوچه ۱۷ و۱۹ \nمشاور شما :امیدی']
# ##################################################
# Unique Values'title'=
# ['۶۰ متر قلهک فول امکانات' '۱۱۵ متری/شمالی رو به آفتاب/اکبری'
#  'اپارتمان ۱۰۰متری طبقه۳و۴ فول دردشت شمالی' ...
#  'آپارتمان ۹۱متر ۲ خواب/شهرک صاحب الزمان' 'آپارتمان ۱۸۰ متری وحدت غربی'
#  'منزل فروشی.  خیابان انقلاب   نرسیده به کارخانه اقا']
# ##################################################
# Unique Values'price_mode'=
# ['مقطوع' 'مجانی' 'Unknown' 'توافقی']
# ##################################################
# Unique Values'price_value'=
# [8.50000000e+09 5.75000000e+09 8.70000000e+09 ... 9.71100000e+09
#  2.37300000e+09 1.24665822e+08]
# ##################################################
# Unique Values'land_size'=
# [6.00000e+01 1.15000e+02 1.00000e+02 ... 1.16100e+03 5.85688e+05
#  1.54800e+03]
# ##################################################
# Unique Values'building_size'=
# [6.00000e+01 1.15000e+02 1.00000e+02 ... 1.16100e+03 5.85688e+05
#  1.54800e+03]
# ##################################################
# Unique Values'deed_type'=
# ['Unknown' 'single_page' 'other' 'written_agreement' 'multi_page' 0]
# ##################################################
# Unique Values'floor'=
# [ 3.  4.  2. nan  5.  1.  0. 30.  7.  8.  6. 12. 13. 19. 16. 11. 10.  9.
#  15. 22. 18. 14. 17. 20. 23. 24. 21. 25. 28. 29. 27. 26.]
# ##################################################
# Unique Values'rooms_count'=
# [2. 3. 4. 5. 1. 6.]
# ##################################################
# Unique Values'total_floors_count'=
# [nan '6' '14' '4' '3' '5' '7' '8' '11' '2' '12' '17' '9' '25' '10' '15'
#  '21' '20' '22' '13' '19' '24' '16' '30+' '26' '18' '30' '29' 0 '23' '27'
#  '28' '4.0' '6.0' '2.0' '5.0' '3.0' '14.0' '25.0' '20.0' '10.0' '12.0'
#  '8.0' '7.0' '13.0' '11.0' '21.0' '19.0']
# ##################################################
# Unique Values'unit_per_floor'=
# [nan '4' '1' '3' '2' '5' '6' '8' '7' 'more_than_8' 0]
# ##################################################
# Unique Values'has_balcony'=
# [0 1]
# ##################################################
# Unique Values'has_elevator'=
# [True False]
# ##################################################
# Unique Values'has_warehouse'=
# [True False]
# ##################################################
# Unique Values'has_parking'=
# [True 0]
# ##################################################
# Unique Values'construction_year'=
# ['۱۳۸۴' '۱۴۰۳' '۱۳۹۳' '۱۳۹۶' '۱۳۸۷' nan '۱۴۰۲' '۱۳۸۸' '۱۳۹۸' '۱۴۰۰' '۱۳۹۲'
#  '۱۴۰۱' '۱۳۹۴' '۱۳۸۳' '۱۳۹۹' '۱۳۹۰' '۱۳۸۵' '۱۳۸۲' '۱۳۹۵' '۱۳۹۱' '۱۳۸۶'
#  '۱۳۸۰' '۱۳۷۵' '۱۳۹۷' '۱۳۷۲' '۱۳۷۴' 'قبل از ۱۳۷۰' '۱۳۸۹' '۱۳۷۹' '۱۳۷۱'
#  '۱۳۸۱' '۱۳۷۳' '۱۳۷۸' '۱۳۷۷' '۱۳۷۶']
# ##################################################
# Unique Values'is_rebuilt'=
# ['Unknown' True False]
# ##################################################
# Unique Values'has_water'=
# [1 False]
# ##################################################
# Unique Values'has_warm_water_provider'=
# ['Unknown' 'package' 'water_heater' 'powerhouse' 0]
# ##################################################
# Unique Values'has_electricity'=
# [1 False]
# ##################################################
# Unique Values'has_gas'=
# [1 False]
# ##################################################
# Unique Values'has_heating_system'=
# ['Unknown' 'shoofaj' 'duct_split' 'heater' 'split' 'floor_heating'
#  'fan_coil' 0 'fireplace']
# ##################################################
# Unique Values'has_cooling_system'=
# ['Unknown' 'air_conditioner' 'water_cooler' 'duct_split' 'split' 0
#  'fan_coil']
# ##################################################
# Unique Values'has_restroom'=
# ['Unknown' 'squat_seat' 'squat' 'seat' 0]
# ##################################################
# Unique Values'has_barbecue'=
# ['Unknown' False True]
# ##################################################
# Unique Values'building_direction'=
# ['Unknown' 'north' 'south' 'east' 'west' 0]
# ##################################################
# Unique Values'has_pool'=
# ['Unknown' False True]
# ##################################################
# Unique Values'has_jacuzzi'=
# ['Unknown' False True]
# ##################################################
# Unique Values'has_sauna'=
# ['Unknown' False True]
# ##################################################
# Unique Values'floor_material'=
# ['Unknown' 'ceramic' 'wood_parquet' 'stone' 'carpet' 'laminate_parquet'
#  'floor_covering' 'mosaic' 0]
# ##################################################
# Unique Values'location_latitude'=
# [        nan 35.7298317  35.7123642  ... 35.58019257 37.50532532
#  34.35023499]
# ##################################################
# Unique Values'location_longitude'=
# [        nan 51.50546646 50.79478073 ... 52.62116241 51.80655289
#  47.08324051]
# ##################################################

# %%
# Fill Some of NaNs (no numerical)
df1["city_slug"]=df1["city_slug"].fillna("Unknown")
df1["neighborhood_slug"]=df1["neighborhood_slug"].fillna("Unknown")
df1["user_type"]=df1["user_type"].fillna("Unknown")
df1["description"]=df1["description"].fillna("Unknown")
df1["title"]=df1["title"].fillna("Unknown")
df1["price_mode"]=df1["price_mode"].fillna("Unknown")
df1["deed_type"]=df1["deed_type"].fillna("Unknown")
df1["has_balcony"]=df1["has_balcony"].fillna("False")
df1["has_elevator"]=df1["has_elevator"].fillna("False")
df1["has_warehouse"]=df1["has_warehouse"].fillna("False")
df1["has_parking"]=df1["has_parking"].fillna("False")
df1["is_rebuilt"]=df1["is_rebuilt"].fillna("Unknown")
df1["has_water"]=df1["has_water"].fillna("True")
df1["has_warm_water_provider"]=df1["has_warm_water_provider"].fillna("Unknown")
df1["has_electricity"]=df1["has_electricity"].fillna("True")
df1["has_gas"]=df1["has_gas"].fillna("True")
df1["has_heating_system"]=df1["has_heating_system"].fillna("Unknown")
df1["has_cooling_system"]=df1["has_cooling_system"].fillna("Unknown")
df1["has_restroom"]=df1["has_restroom"].fillna("Unknown")
df1["has_barbecue"]=df1["has_barbecue"].fillna("Unknown")
df1["building_direction"]=df1["building_direction"].fillna("Unknown")
df1["has_pool"]=df1["has_pool"].fillna("Unknown")
df1["has_jacuzzi"]=df1["has_jacuzzi"].fillna("Unknown")
df1["has_sauna"]=df1["has_sauna"].fillna("Unknown")
df1["floor_material"]=df1["floor_material"].fillna("Unknown")

# %%
col = "rooms_count"
df1_rooms_count_dict={
    "یک":2,
    "دو":3,
    "سه":4,
    "چهار":5,
    "بدون اتاق":1,
    "پنج یا بیشتر":6}
df1[col]=df1[col].astype(str).str.strip()
df1[col]=df1[col].replace(df1_rooms_count_dict)
df1[col]=pd.to_numeric(df1[col],errors="coerce").astype("Int64")

# %%
col = "floor"
df1_floor_dict={
    "-1":0,
    "+30":30}
df1[col]=df1[col].replace(df1_floor_dict)
df1[col]=pd.to_numeric(df1[col],errors="coerce").astype("Int64")

# %%
col = "unit_per_floor"
per_floor_dict={
    "more_than_8" : 8}
df1[col]=df1[col].replace(per_floor_dict)
df1[col]=pd.to_numeric(df1[col],errors="coerce").astype("Int64")

# %%
col = "total_floors_count"
floor_count_dict={
    "+30":30}
df1[col]=df1[col].replace(floor_count_dict)
df1[col]=pd.to_numeric(df1[col],errors="coerce").astype("Int64")

# %%
df1_dict1={
    "true":"True",
    "false":"False"}
df1=df1.map(lambda x:df1_dict1.get(x,x))

# %%
df1_dict2={
    "unselect":0,
    "True False":0,
    "True":1,
    "False":0}
df1=df1.map(lambda x:df1_dict2.get(x,x))

# %%
sns.catplot(data=df1 , x="rooms_count", kind="count")
plt.xticks(rotation=45,ha="right")
plt.show()

# %%
df1["price_value"]=df1["price_value"].fillna(1740030000)
df1["land_size"]=df1["land_size"].fillna(df1["building_size"])
df1["building_size"]=df1["building_size"].fillna(df1["land_size"])
df1["rooms_count"]=df1["rooms_count"].fillna(3)
df1["location_latitude"]=df1["location_latitude"].fillna(35.046600)
df1["location_longitude"]=df1["location_longitude"].fillna(51.546260)

# %%
df1.describe()
# Out:
#         price_value     land_size  building_size          floor  \
# count  4.244420e+05  4.244420e+05   4.244420e+05  302373.000000
# mean   1.547958e+10  1.483944e+03   1.085004e+03       2.851442
# std    5.286585e+11  7.627807e+04   6.493766e+04       2.215483
# min    0.000000e+00  1.000000e+00   1.000000e+00       0.000000
# 25%    1.720000e+09  7.700000e+01   7.500000e+01       1.000000
# 50%    3.100000e+09  1.050000e+02   1.000000e+02       2.000000
# 75%    6.050000e+09  1.600000e+02   1.370000e+02       4.000000
# max    1.000000e+14  1.000000e+07   1.000000e+07      30.000000
#
#          rooms_count  total_floors_count  unit_per_floor  location_latitude  \
# count  424442.000000            186553.0        184553.0      424442.000000
# mean        3.087694            4.955686        2.337621          35.125567
# std         0.841966            2.758238        1.431019           1.755553
# min         1.000000                 0.0             0.0          23.636976
# 25%         3.000000                 4.0             1.0          35.046600
# 50%         3.000000                 4.0             2.0          35.297815
# 75%         3.000000                 5.0             3.0          35.772238
# max         6.000000                30.0             8.0          40.358055
#
#        location_longitude
# count       424442.000000
# mean            51.563406
# std              2.433289
# min             43.774818
# 25%             51.020851
# 50%             51.546260
# 75%             51.546260
# max             62.558594

# %%
df1["total_floors_count"]=df1["total_floors_count"].fillna(5)
df1["unit_per_floor"]=df1["unit_per_floor"].fillna(2)
df1["floor"]=df1["floor"].fillna(3)

# %%
df1.isnull().sum()
# Out:
# cat2_slug                  0
# cat3_slug                  0
# city_slug                  0
# neighborhood_slug          0
# user_type                  0
# description                0
# title                      0
# price_mode                 0
# price_value                0
# land_size                  0
# building_size              0
# deed_type                  0
# floor                      0
# rooms_count                0
# total_floors_count         0
# unit_per_floor             0
# has_balcony                0
# has_elevator               0
# has_warehouse              0
# has_parking                0
# construction_year          0
# is_rebuilt                 0
# has_water                  0
# has_warm_water_provider    0
# has_electricity            0
# has_gas                    0
# has_heating_system         0
# has_cooling_system         0
# has_restroom               0
# has_barbecue               0
# building_direction         0
# has_pool                   0
# has_jacuzzi                0
# has_sauna                  0
# floor_material             0
# location_latitude          0
# location_longitude         0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 424442 entries, 0 to 424441
# Data columns (total 37 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   cat2_slug                424442 non-null  object
#  1   cat3_slug                424442 non-null  object
#  2   city_slug                424442 non-null  object
#  3   neighborhood_slug        424442 non-null  object
#  4   user_type                424442 non-null  object
#  5   description              424442 non-null  object
#  6   title                    424442 non-null  object
#  7   price_mode               424442 non-null  object
#  8   price_value              424442 non-null  float64
#  9   land_size                424442 non-null  float64
#  10  building_size            424442 non-null  float64
#  11  deed_type                424442 non-null  object
#  12  floor                    424442 non-null  float64
#  13  rooms_count              424442 non-null  float64
#  14  total_floors_count       424442 non-null  Int64
#  15  unit_per_floor           424442 non-null  Int64
#  16  has_balcony              424442 non-null  object
#  17  has_elevator             424442 non-null  object
#  18  has_warehouse            424442 non-null  object
#  19  has_parking              424442 non-null  object
#  20  construction_year        424442 non-null  object
#  21  is_rebuilt               424442 non-null  object
#  22  has_water                424442 non-null  object
#  23  has_warm_water_provider  424442 non-null  object
#  24  has_electricity          424442 non-null  object
#  25  has_gas                  424442 non-null  object
#  26  has_heating_system       424442 non-null  object
#  27  has_cooling_system       424442 non-null  object
#  28  has_restroom             424442 non-null  object
#  29  has_barbecue             424442 non-null  object
#  30  building_direction       424442 non-null  object
#  31  has_pool                 424442 non-null  object
#  32  has_jacuzzi              424442 non-null  object
#  33  has_sauna                424442 non-null  object
#  34  floor_material           424442 non-null  object
#  35  location_latitude        424442 non-null  float64
#  36  location_longitude       424442 non-null  float64
# dtypes: Int64(2), float64(7), object(28)
# memory usage: 120.6+ MB

# %%
# Save new csv file
df1.to_csv("divar_new.csv",index=False)
